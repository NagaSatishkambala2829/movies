# %%
print("hi")
# Out:
# hi

# %%
import pandas as pd

# %%
data=pd.read_csv("/home/placement/Downloads/fiat500.csv")
data
# Out:
#         ID   model  engine_power  age_in_days      km  previous_owners  \
# 0        1  lounge            51          882   25000                1
# 1        2     pop            51         1186   32500                1
# 2        3   sport            74         4658  142228                1
# 3        4  lounge            51         2739  160000                1
# 4        5     pop            73         3074  106880                1
# ...    ...     ...           ...          ...     ...              ...
# 1533  1534   sport            51         3712  115280                1
# 1534  1535  lounge            74         3835  112000                1
# 1535  1536     pop            51         2223   60457                1
# 1536  1537  lounge            51         2557   80750                1
# 1537  1538     pop            51         1766   54276                1
#
#             lat        lon  price
# 0     44.907242   8.611560   8900
# 1     45.666359  12.241890   8800
# ...

# %% [markdown]
# data1=pd.read_csv("/home/placement/Downloads/fiat500.csv")

# %%
list (data)
# Out:
# ['srno', 'movie', 'year', 'rating', 'time']

# %%
data['model']=data['model'].map({'launge':1,'pop':2,'spot':3})
data
# Out:
#         ID  model  engine_power  age_in_days      km  previous_owners  \
# 0        1    NaN            51          882   25000                1
# 1        2    NaN            51         1186   32500                1
# 2        3    NaN            74         4658  142228                1
# 3        4    NaN            51         2739  160000                1
# 4        5    NaN            73         3074  106880                1
# ...    ...    ...           ...          ...     ...              ...
# 1533  1534    NaN            51         3712  115280                1
# 1534  1535    NaN            74         3835  112000                1
# 1535  1536    NaN            51         2223   60457                1
# 1536  1537    NaN            51         2557   80750                1
# 1537  1538    NaN            51         1766   54276                1
#
#             lat        lon  price
# 0     44.907242   8.611560   8900
# 1     45.666359  12.241890   8800
# ...
